# %%
import numpy as np
import matplotlib.pyplot as plt
import pymc3 as pm

from matplotlib import animation, rc
# %matplotlib inline

# %% [markdown]
# ## Bayes Rule
# \begin{align}
# p(\mu|x) = \frac{p(x|\mu)p(\mu)}{p(x)}
# \end{align}
# However, it is easier to express in the following form since the denominator is a constant that requires the numerator to integrate to one.
# \begin{align}
# p(\mu|x) \propto p(x|\mu)p(\mu)
# \end{align}
#
# Suppose we have a prior distribution that is (relatively uninformative) on $\mu$ (say normally distributed with a standard deviation of 20). And say that the true distribution was with a mean of 4 and standard deviation of 1. We will see in the following demonstration of how the mean converges to 4 and how the variance decreases.
#
# ### The mathemetical way
# \begin{align}
# p(\mu|x_1,...,x_N) &\propto p(x_1|\mu)p(x_2|\mu)...p(x_N|\mu)p(\mu)\\
# &\propto\exp\left(-\frac{1}{2}\left((x_1-\mu)^2+(x_2-\mu)^2+...+(x_N-\mu)^2\right)\right)\exp\left(-\frac{1}{2}\frac{\mu}{20^2}\right)\\
# &\propto\exp\left(\mu^2\left(N+\frac{1}{20^2}\right)-2\sum_{i=1}^Nx_i\mu\right)\\
# & = \mathcal{N}\left(\frac{\sum x_i}{N+\frac{1}{20^2}},\frac{1}{N+\frac{1}{20^2}}\right)
# \end{align}

# %%
σ_μ = 20
μ = σ_μ * np.random.randn(2000) # prior distribution
plt.hist(μ, 50)
plt.show()

# %%
sum_x = 0
N = 0

data = []
y = 4 + np.random.randn(100,1) #observations
for i in range(100):
    sample = y[i]
    sum_x += sample
    N += 1
    posterior_mean = sum_x/(N+1/σ_μ**2)
    posterior_var = 1/(N+1/σ_μ**2)
    posterior_samples = posterior_mean + np.sqrt(posterior_var) * np.random.randn(2000)
    data.append(posterior_samples)

# %%
fig, ax = plt.subplots()
plt.close()
ax.set_xlim(( -4, 8))
ax.set_ylim((-1,250))
line1, = ax.plot([], [], lw=2)
# animation function: this is called sequentially
def animate(i):
    n, bins = np.histogram(data[i], bins=100, range=(-5,5))
  
    line1.set_data(bins[:-1], n)
    return (line1,)
anim = animation.FuncAnimation(fig, animate, frames=100, interval=100, blit=True)
rc('animation', html='jshtml')
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgb55a8b3f2b7d42dea53db9393603c1b0">
#     <br>
#     <input id="_anim_sliderb55a8b3f2b7d42dea53db9393603c1b0" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animb55a8b3f2b7d42dea53db9393603c1b0.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animb55a8b3f2b7d42dea53db9393603c1b0.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectb55a8b3f2b7d42dea53db9393603c1b0" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb55a8b3f2b7d42dea53db9393603c1b0";
#     var slider_id = "_anim_sliderb55a8b3f2b7d42dea53db9393603c1b0";
#     var loop_select_id = "_anim_loop_selectb55a8b3f2b7d42dea53db9393603c1b0";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAHtVJREFUeJzt3Xt0lOWh7/HfJEO4hnBLQpIhXAyS\
# GxBCEPF2ijGAHBvKpVSKWyxIzqK1VtH20H1qN3qOQN26C1a6NKfgjvZIqruVsJSLgHcE4xSCQAhG\
# SDAZQi4SzAUScpnzx8AIJopKknee4ftZq2slb2be/N61Sn4+z/vM89rcbrdbAAAYJsDqAAAAfB8U\
# GADASBQYAMBIFBgAwEgUGADASBQYAMBIFBgAwEgUGADASBQYAMBIFBgAwEgUGADASBQYAMBIFBgA\
# wEgUGADASBQYAMBIFBgAwEgUGADASBQYAMBIFBgAwEgUGADASBQYAMBIFBgAwEgUGADASBQYAMBI\
# FBgAwEgUGADASBQYAMBIFBgAwEgUGADASBQYAMBIlhRYSUmJJk+erLi4OCUkJGjNmjWSpOXLlysq\
# KkpJSUlKSkrS5s2bve9ZuXKlYmJiNGrUKG3bts2K2AAAH2Jzu93urv6lZWVlKisrU3JysmprazV+\
# /Hht3LhRL7/8svr06aOHH374ktfn5+dr3rx5ys3N1YkTJ3Tbbbfpk08+UWBgYFdHBwD4CEtGYBER\
# EUpOTpYkBQcHKy4uTi6X62tfn5OTozvvvFPdu3fX8OHDFRMTo9zc3K6KCwDwQZbfAysuLta+ffs0\
# ceJESdIzzzyjMWPGaOHChaqurpYkuVwuDRkyxPseh8PxjYUHAPB/dit/eV1dnWbPnq3Vq1erb9++\
# WrJkiR555BHZbDY98sgjeuihh7R+/Xq1N8tps9naHMvMzFRmZqYkqaCgQLGxsZ1+DQDgT4qLi1VV\
# VWV1jG/FsgJramrS7NmzNX/+fM2aNUuSFB4e7v354sWLdccdd0jyjLhKSkq8PystLVVkZGSbc2Zk\
# ZCgjI0OSlJKSIqfT2ZmXAAB+JyUlxeoI35olU4hut1uLFi1SXFycli5d6j1eVlbm/frVV19VYmKi\
# JCk9PV3Z2dlqbGxUUVGRCgsLdd1113V5bgCA77BkBLZr1y69+OKLGj16tJKSkiRJK1as0IYNG5SX\
# lyebzaZhw4bpueeekyQlJCRo7ty5io+Pl91u19q1a1mBCABXOUuW0XcFphAB4Lsz6W+n5asQAQD4\
# PigwAICRKDAAgJEoMACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAAgJEo\
# MACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAA\
# gJEoMACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAAgJEoMACAkSgwAICRKDAAgJEoMACAkSwpsJKS\
# Ek2ePFlxcXFKSEjQmjVrJEmnTp1SWlqaRo4cqbS0NFVXV0uS3G637r//fsXExGjMmDHau3evFbEB\
# AD7EkgKz2+166qmndPjwYe3Zs0dr165Vfn6+Vq1apdTUVBUWFio1NVWrVq2SJG3ZskWFhYUqLCxU\
# ZmamlixZYkVsAIAPsaTAIiIilJycLEkKDg5WXFycXC6XcnJytGDBAknSggULtHHjRklSTk6O7r77\
# btlsNl1//fU6ffq0ysrKrIgOAPARlt8DKy4u1r59+zRx4kSVl5crIiJCkqfkKioqJEkul0tDhgzx\
# vsfhcMjlclmSFwDgG+xW/vK6ujrNnj1bq1evVt++fb/2dW63u80xm83W5lhmZqYyMzMlSZWVlR0X\
# FADgcywbgTU1NWn27NmaP3++Zs2aJUkKDw/3Tg2WlZUpLCxMkmfEVVJS4n1vaWmpIiMj25wzIyND\
# TqdTTqdToaGhXXAVAACrWFJgbrdbixYtUlxcnJYuXeo9np6erqysLElSVlaWZsyY4

# %% [markdown]
# ## The Probabilistic programming way:
# First write down the data model (in this case the data generation process):
# \begin{align}
# \mu &\sim \mathcal{N}(0, 20) \\
# y &\sim \mathcal{N}(\mu, 1)
# \end{align}

# %%
n_samples = 500

with pm.Model() as model:
    μ = pm.Normal('mu', mu=0, sd=σ_μ)
    likelihood = pm.Normal('y', mu=μ, sd=1, observed=y)
    trace = pm.sample(n_samples, njobs=4)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu]
# Sampling 4 chains: 100%|██████████| 4000/4000 [00:01<00:00, 3179.09draws/s]
# The acceptance probability does not match the target. It is 0.8810549893603662, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c0af2be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c0ad0a7f0>]],
#       dtype=object)

# %%
trace['mu'].shape
# Out:
# (2000,)

# %% [markdown]
# ### Modified Model
# \begin{align}
# \mu &\sim \mathcal{N}(0, 20) \\
# \sigma &\sim exp(\lambda) \\
# y &\sim \mathcal{N}(\mu, \sigma)
# \end{align}

# %%
with pm.Model() as model:
    μ = pm.Normal('mu', mu=0, sd=σ_μ)
    σ = pm.Exponential('sigma', lam=1/5)
    likelihood = pm.Normal('y', mu=μ, sd=1, observed=y)
    trace = pm.sample(n_samples, njobs=4)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, mu]
# Sampling 4 chains: 100%|██████████| 4000/4000 [00:01<00:00, 2375.82draws/s]

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c0cab1278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c0cbb5940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c0cbe8668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c0cc1c160>]],
#       dtype=object)
